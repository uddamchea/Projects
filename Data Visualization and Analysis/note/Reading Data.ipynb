# %% [markdown]
# # Read Data
# ## CSV

# %%
# %config Completer.use_jedi = False

import pandas as pd
from pandas import DataFrame

# %%
df = pd.read_csv("note.csv")

# %%
df
# Out:
#    id                name  age               species   location
# 0   1               Chunk   34                Jaguar      Attic
# 1   2                Wind   99                  Newt   Basement
# 2   3  Underrated Thunder   74      Macaroni Penguin   Basement
# 3   4                 Axe   23        Long-Eared Owl     Garage
# 4   5        Wild Isotope   28      Humboldt Penguin      Attic
# 5   6          Night Star   26                  Newt     Garage
# 6   7        Random Bully   52             Armadillo  Back yard
# 7   8        Cunning Fury   38  Pink Fairy Armadillo  Back yard
# 8   9       Evening Chunk   50                  Newt   Basement
# 9  10             Thunder   38                Jaguar      Attic

# %%
df.dtypes
# Out:
# id           int64
# name        object
# age          int64
# species     object
# location    object
# dtype: object

# %%
df.shape
# Out:
# (10, 5)

# %%
pd.read_csv("note.csv").head()
# Out:
#    id                name  age           species  location
# 0   1               Chunk   34            Jaguar     Attic
# 1   2                Wind   99              Newt  Basement
# 2   3  Underrated Thunder   74  Macaroni Penguin  Basement
# 3   4                 Axe   23    Long-Eared Owl    Garage
# 4   5        Wild Isotope   28  Humboldt Penguin     Attic

# %% [markdown]
# # SQL

# %%
import sqlite3
import sqlalchemy as sqla

# %%
#conn = sqlite3.connect(filename)

# %%
#pd.read_sql("select * from zoo;", conn)

# %%
#conn.close()

# %%
#with sqlite3.connect(filename) as conn:
    #df = pd.read_sql("select * from filename;", conn)

# %%
#db = sqla.create_engine("sqlite://zoo.sqlite3")

# %%
#conn = db.connect()

# %%
#zoo is a table not a file
#file can contains multiple tables
#pd.read_sql("zoo", conn)

# %% [markdown]
# # Work with API

# %%
import requests

# %%
url = "http://cat-fact.herokuapp.com/facts"

# %%
data = requests.get(url).json()

# %%
data
# Out:
# [{'status': {'verified': True, 'sentCount': 1},
#   '_id': '58e008800aac31001185ed07',
#   'user': '58e007480aac31001185ecef',
#   'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'type': 'cat',
#   'createdAt': '2018-03-06T21:20:03.505Z',
#   'deleted': False,
#   'used': False},
#  {'status': {'verified': True, 'sentCount': 1},
#   '_id': '58e008630aac31001185ed01',
#   'user': '58e007480aac31001185ecef',
#   'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'type': 'cat',
#   'createdAt': '2018-02-07T21:20:02.903Z',
#   'deleted': False,
#   'used': False},
#  {'status': {'verified': True, 'sentCount': 1},
#   '_id': '58e00a090aac31001185ed16',
# ...

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                                status                       _id  \
# 0  {'verified': True, 'sentCount': 1}  58e008800aac31001185ed07
# 1  {'verified': True, 'sentCount': 1}  58e008630aac31001185ed01
# 2  {'verified': True, 'sentCount': 1}  58e00a090aac31001185ed16
# 3  {'verified': True, 'sentCount': 1}  58e009390aac31001185ed10
# 4  {'verified': True, 'sentCount': 1}  58e008780aac31001185ed05
#
#                        user  \
# 0  58e007480aac31001185ecef
# 1  58e007480aac31001185ecef
# 2  58e007480aac31001185ecef
# 3  58e007480aac31001185ecef
# 4  58e007480aac31001185ecef
#
#                                                 text  __v source  \
# 0  Wikipedia has a recording of a cat meowing, be...    0   user
# 1  When cats grimace, they are usually "taste-sce...    0   user
# 2  Cats make more than 100 different sounds where...    0   user
# 3  Most cats are lactose intolerant, and milk can...    0   user
# 4  Owning a cat can reduce the risk of stroke and...    0   user
#
# ...

# %%
df = pd.json_normalize(data)

# %%
df
# Out:
#                         _id                      user  \
# 0  58e008800aac31001185ed07  58e007480aac31001185ecef
# 1  58e008630aac31001185ed01  58e007480aac31001185ecef
# 2  58e00a090aac31001185ed16  58e007480aac31001185ecef
# 3  58e009390aac31001185ed10  58e007480aac31001185ecef
# 4  58e008780aac31001185ed05  58e007480aac31001185ecef
#
#                                                 text  __v source  \
# 0  Wikipedia has a recording of a cat meowing, be...    0   user
# 1  When cats grimace, they are usually "taste-sce...    0   user
# 2  Cats make more than 100 different sounds where...    0   user
# 3  Most cats are lactose intolerant, and milk can...    0   user
# 4  Owning a cat can reduce the risk of stroke and...    0   user
#
#                   updatedAt type                 createdAt  deleted   used  \
# 0  2020-08-23T20:20:01.611Z  cat  2018-03-06T21:20:03.505Z    False  False
# 1  2020-08-23T20:20:01.611Z  cat  2018-02-07T21:20:02.903Z    False  False
# ...

# %%
df.text
# Out:
# 0    Wikipedia has a recording of a cat meowing, be...
# 1    When cats grimace, they are usually "taste-sce...
# 2    Cats make more than 100 different sounds where...
# 3    Most cats are lactose intolerant, and milk can...
# 4    Owning a cat can reduce the risk of stroke and...
# Name: text, dtype: object

# %% [markdown]
# # Saving File

# %%
df.to_csv("cat-fact.csv", index=False)

# %%
pd.read_csv("cat-fact.csv")
# Out:
#                         _id                      user  \
# 0  58e008800aac31001185ed07  58e007480aac31001185ecef
# 1  58e008630aac31001185ed01  58e007480aac31001185ecef
# 2  58e00a090aac31001185ed16  58e007480aac31001185ecef
# 3  58e009390aac31001185ed10  58e007480aac31001185ecef
# 4  58e008780aac31001185ed05  58e007480aac31001185ecef
#
#                                                 text  __v source  \
# 0  Wikipedia has a recording of a cat meowing, be...    0   user
# 1  When cats grimace, they are usually "taste-sce...    0   user
# 2  Cats make more than 100 different sounds where...    0   user
# 3  Most cats are lactose intolerant, and milk can...    0   user
# 4  Owning a cat can reduce the risk of stroke and...    0   user
#
#                   updatedAt type                 createdAt  deleted   used  \
# 0  2020-08-23T20:20:01.611Z  cat  2018-03-06T21:20:03.505Z    False  False
# 1  2020-08-23T20:20:01.611Z  cat  2018-02-07T21:20:02.903Z    False  False
# ...

# %%
df.to_html("cat-fact.html")
